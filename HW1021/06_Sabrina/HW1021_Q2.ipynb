# %% [markdown]
# 9. This problem has to do with odds.

# %% [markdown]
#  (a) On average, what fraction of people with an odds of 0.37 of
#  defaulting on their credit card payment will in fact default?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Rearrange the formula：
#
# ![image.png](attachment:image.png)

# %% [markdown]
# With the given odds = 0.37,
#
# ![image.png](attachment:image.png)

# %% [markdown]
# On average, about 27% of people with an odds of 0.37 will in fact default.

# %% [markdown]
#  (b) Suppose that an individual has a 16% chance of defaulting on
#  her credit card payment. What are the odds that she will default?

# %% [markdown]
# According to,
#
# ![image.png](attachment:image.png)

# %% [markdown]
# With given p = 0.16,
#
# ![image.png](attachment:image.png)

# %% [markdown]
# So, the odds that the individual will default are 0.19.
