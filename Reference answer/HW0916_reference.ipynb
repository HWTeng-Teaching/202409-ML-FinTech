# %% [markdown]
# #Machine Learning and FinTech 2024/25
# ##Homework 0916 reference answer
# ###It is not a model answer, just for reference
# By TA, Chan Nok Hang

# %% [markdown]
# #Question 8
# ##part a
# First we use the pd.read_csv() function to read the data into Python. Then call the loaded data as college.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a2b87195-a297-4360-98a1-240ced453a8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2b87195-a297-4360-98a1-240ced453a8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
college=pd.read_csv('College.csv')
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# #part b

# %%
college2 = pd.read_csv('College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'},axis=1)
college3 = college3.set_index('College')

# %%
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college = college3

# %% [markdown]
# #part c
# Use the describe() method of to produce a numerical summary
# of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# #part d
# Use the pd.plotting.scatter_matrix() function to produce a scatterplot matrix of the frst columns [Top10perc, Apps, Enroll].

# %%
pd.plotting.scatter_matrix(college[['Top10perc','Apps','Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# #part e
# Use the boxplot() method of college to produce side-by-side
# boxplots of Outstate versus Private.

# %%
import matplotlib.pyplot as plt
box=college.boxplot(column='Outstate',by='Private',vert=False)
box.get_figure().suptitle('')
plt.title('Boxplot of Outstate vs. Private')
plt.xlabel('Outstate')
plt.ylabel('Private')
# Out:
# Text(0, 0.5, 'Private')

# %% [markdown]
# #part f
# Create a new qualitative variable, called Elite, by binning the
# Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%.
#
# Use the value_counts() method of college['Elite'] to see how
# many elite universities there are. Finally, use the boxplot() method
# again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college['Elite'] = pd.cut(college['Top10perc']/college['Enroll'],[0,0.5,1],labels=['No', 'Yes'])

# %%
pd.value_counts(college['Elite'])
# Out:
# No     775
# Yes      2
# Name: Elite, dtype: int64

# %%
college.boxplot(column='Outstate',by='Elite',vert=False).get_figure().suptitle('')
plt.title('Boxplot of Outstate vs. Elite')
plt.xlabel('Outstate')
plt.ylabel('Elite')
# Out:
# Text(0, 0.5, 'Elite')

# %% [markdown]
# #part g
# Use the plot.hist() method of college to produce some histograms with difering numbers of bins for a few of the quantitative variables.

# %%
# Select a few quantitative variables to create histograms
selected_variables = ['Top10perc', 'Terminal', 'Personal', 'Expend']

# Create subplots with 2 rows and 2 columns
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Flatten the axes array for easy iteration
axes = axes.ravel()

# Create histograms with different numbers of bins for each selected variable
for i, var in enumerate(selected_variables):
    college[var].plot.hist(ax=axes[i], bins=i * 10 + 50)  # Adjust the number of bins as needed
    axes[i].set_title(f'Histogram of {var}')
    axes[i].set_xlabel(var)
    axes[i].set_ylabel('Frequency')

# Ensure proper layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #part h (reference 1)
# Continue exploring the data, and provide a brief summary of what you discover.
#
# To further explore the data, I conduct a correlation matrix and use seaborn heatmap to visualize the matrix. After that, as the results, we can discover that the Outstate variable are positive correlated to the perc.alumni, also I discover that the Outstate variable are positive correlated to the Grad.Rate.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
import seaborn as sns

# %%
correlations = college.corr()
college_corr = correlations['perc.alumni']
print(college_corr)
college_corr = correlations['Grad.Rate']
print(college_corr)
sns.heatmap(correlations)
# Out:
# <ipython-input-32-7b289ec98c27>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = college.corr()
# Apps          -0.090226
# Accept        -0.159990
# Enroll        -0.180794
# Top10perc      0.455485
# Top25perc      0.417864
# F.Undergrad   -0.229462
# P.Undergrad   -0.280792
# Outstate       0.566262
# Room.Board     0.272363
# Books         -0.040208
# Personal      -0.285968
# PhD            0.249009
# Terminal       0.267130
# S.F.Ratio     -0.402929
# perc.alumni    1.000000
# Expend         0.417712
# Grad.Rate      0.490898
# Name: perc.alumni, dtype: float64
# Apps           0.146755
# Accept         0.067313
# Enroll        -0.022341
# Top10perc      0.494989
# Top25perc      0.477281
# F.Undergrad   -0.078773
# P.Undergrad   -0.257001
# Outstate       0.571290
# Room.Board     0.424942
# ...

# %% [markdown]
# ## part h reference 2

# %%
# Explore the relationship between 'perc.alumni' and 'Outstate'
plt.scatter(college['perc.alumni'], college['Outstate'])
plt.xlabel('perc.alumni')
plt.ylabel('Outstate')
plt.title('perc.alumni vs. Outstate')
plt.show()

# Calculate the correlation between 'Outstate' and 'F.Undergrad'
corr_outstate_funder = college['Outstate'].corr(college['F.Undergrad'])
print(f"Correlation between Outstate and F.Undergrad: {corr_outstate_funder}")


# Investigate the relationship between 'Private' and 'Grad.Rate'
college.boxplot('Grad.Rate', 'Private')
plt.title('Grad.Rate by Private Status')
plt.show()
# Out:
# Correlation between Outstate and F.Undergrad: -0.2157419987704193

# %% [markdown]
# ### - There appears is a positive correlation between 'perc.alumni' and 'Outstate'.
#
# ### - There is a slight negative correlation between Outstate and F.Undergrad
#
# ### - The distribution of 'Expend' seems to be skewed towards the lower end.
#
# ### - There is a noticeable difference in the Grad.Rate between private and public institutions.

# %% [markdown]
# #Question 10
# ##part a
# Load in the boston dataset from ISLP

# %%
pip install ISLP
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 32.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 350.7/350.7 kB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 522.2/522.2 kB 47.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.7/727.7 kB 51.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 57.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 61.1 MB/s eta 0:00:00
# ...
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4031 sha256=69fd5b724071a8fb8d1f2ba2c95d06db1907e5d0031f4e65745d6dead828b338
#   Stored in directory: /root/.cache/pip/wheels/25/cc/e0/ef2969164144c899fedb22b338f6703e2b9cf46eeebf254991
# Successfully built autograd-gamma
# ...
#   Attempting uninstall: numpy
# ...

# %%
# Load the Boston data set
from ISLP import load_data
boston = load_data('Boston')
boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# #part b (reference 1)
# The rows in the Boston data set represent different suburbs in Boston, and the columns represent various attributes or features related to those suburbs, such as crime rate, property values, tax rates, etc.

# %%
num_rows, num_columns = boston.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 506
# Number of columns: 13

# %% [markdown]
# ## b (reference 2)

# %%
# Check the dimensions of the dataset (number of rows and columns)
print(f"Boston dataset has {boston.shape[0]} rows and {boston.shape[1]} columns.", end='\n\n')

# Check the column names to understand what each represents
print(f"Each row represents a suburb in Boston.", end='\n\n')
print(boston.columns, end='\n\n')
# Out:
# Boston dataset has 506 rows and 13 columns.
#
# Each row represents a suburb in Boston.
#
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# Each column represents:
#
#
# * **crim**: per capita crime rate by town. 每個城鎮的人均犯罪率
# * **zn**: proportion of residential land zoned for lots over 25,000 sq.ft. 住宅用地佔比（超過 25,000 平方英尺的地塊比例）
#
# * **indus**: proportion of non-retail business acres per town. 每個城鎮的非零售商業用地比例
#
# * **chas**: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise). 查爾斯河虛擬變量
#
# * **nox**: nitrogen oxides concentration (parts per 10 million). 氮氧化物濃度（每千萬份中的濃度）
#
# * **rm**: average number of rooms per dwelling. 每個住宅的平均房間數
#
# * **age**: proportion of owner-occupied units built prior to 1940. 1940 年之前建造的自住單位的比例
#
# * **dis**: weighted mean of distances to five Boston employment centres. 到波士頓五個就業中心的加權平均距離
#
# * **rad**: index of accessibility to radial highways. 輻射狀高速公路的可達性指數
#
# * **tax**: full-value property-tax rate per $10,000. 每 10,000 美元的財產稅率
#
# * **ptratio**: pupil-teacher ratio by town. 每個城鎮的師生比
#
# * **lstat**: lower status of the population (percent). 低收入人群的比例（百分比）
#
# * **medv**: median value of owner-occupied homes in $1000s. 自住住房的中位數價值（以千美元為單位）

# %%
# Get a summary of the dataset (optional, for more detail)
print(boston.describe())
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# #part c
# In this part, we conduct pairwise scatterplots of the predictors to visualize relationships between different predictors. Then, I find out that some predictors have an approximately linear relationship, which are nox and dis, rm and medv, rm and lstat, lstat and medv.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.scatter(boston.nox,boston.dis)
plt.title('scatterplot of nox vs. dis')
plt.xlabel('nox')
plt.ylabel('dis')
plt.show()

plt.scatter(boston.rm,boston.medv)
plt.title('scatterplot of rm vs. medv')
plt.xlabel('rm')
plt.ylabel('medv')
plt.show()

plt.scatter(boston.rm,boston.lstat)
plt.title('scatterplot of rm vs. lstat')
plt.xlabel('rm')
plt.ylabel('lstat')
plt.show()

plt.scatter(boston.lstat,boston.medv)
plt.title('scatterplot of lstat vs. medv')
plt.xlabel('lstat')
plt.ylabel('medv')
plt.show()

# %% [markdown]
# #part  d (reference 1)
# To determine the relationship between predictors and the per capita crime rate, I calculate correlations using the corr() method of the DataFrame. Besides, I also use seaborn heatmap to visualize the correlation matrix.
#
# According to the results, the index of accessibility to radial highways is positively correlated to the crime rate, this may be because the higher the accessibility to radial highways, the more chance to escape after committing a crime.

# %%
import pandas as pd
import seaborn as sns

# %%
correlations = boston.corr()
crime_corr = correlations['crim']
print(crime_corr)
sns.heatmap(correlations)
print(f"Maximum of correlation with crime rates:{max(correlations.iloc[0,1:])}")
# Out:
# crim       1.000000
# zn        -0.200469
# indus      0.406583
# chas      -0.055892
# nox        0.420972
# rm        -0.219247
# age        0.352734
# dis       -0.379670
# rad        0.625505
# tax        0.582764
# ptratio    0.289946
# lstat      0.455621
# medv      -0.388305
# Name: crim, dtype: float64
# Maximum of correlation with crime rates:0.6255051452626024

# %% [markdown]
# ## part d (reference 2)

# %%
correlation_matrix = boston.corr()

# Display the correlation of crim with other predictors
print(correlation_matrix['crim'].sort_values(ascending=False))

# Visualize scatterplots for variables highly correlated with crim
corr_columns = correlation_matrix['crim'].abs().sort_values(ascending=False).index
# Out:
# crim       1.000000
# rad        0.625505
# tax        0.582764
# lstat      0.455621
# nox        0.420972
# indus      0.406583
# age        0.352734
# ptratio    0.289946
# chas      -0.055892
# zn        -0.200469
# rm        -0.219247
# dis       -0.379670
# medv      -0.388305
# Name: crim, dtype: float64

# %%
radcrim = sns.boxplot(x="rad", y="crim", data=boston)

# %%
plt.scatter(boston['tax'], boston['crim'])
plt.xlabel('tax')
plt.ylabel('crim');

# %%
plt.scatter(boston['lstat'], boston['crim'])
plt.xlabel('lstat')
plt.ylabel('crim');

# %% [markdown]
# Findings:
# * **rad (Index of accessibility to radial highways)**: When rad is equal to 24 (highest value), average crim is much higher and range is much larger.
# * **tax (full-value property-tax rate per $10,000)**: When tax is equal to 666, average crim is much higher and crim range is much larger.
# * **lstat (lower status of the population (percent))**: For lower values of LSTAT (< 10), CRIM is always under 10. For LSTAT > 10, there is a wider spread of CRIM. For LSTAT < 20, a large proportion of the data points is very close to CRIM = 0.

# %% [markdown]
# #part e (reference 1)
# To find out the answer of part e, we can analyze the data by examining summary statistics for each predictor column, and this will give us an overview of the range and distribution of crime rates, tax rates, and pupil-teacher ratios. Also, we can use box to spot out the outliers of data of these columns.
#
# According to the summary statistics, It did have some of the suburbs of Boston appear to have particularly high crime rates. As we can see, the crime rate has a noticeable maximum of 88.9762, and this is exceptionally high compared to the median is only 0.2565, and even the upper quartile only 3.6771. And for tax rates, having a maximum tax rates of 711 while median is 330 and the upper quartile is 666, not a big gap. For the pupil-teacher ratios, things become normal, not abnormally high. Note that the maximum pt ratio 22 is close to both the median and upper quartile when compared to the situation of crime rates and tax rates.
#
# With the boxplot, we may say that not only do some of the suburbs of Boston appear to have particularly high crime rates, instead it looks like most of them are high in crime rates. In the tax rates boxplot, we can see that the plot looks clean with no outliers, so it may represent that there are no suburbs of Boston having particularly high tax rates. The last boxplot shows that some suburbs of Boston have comparatively low in pupil-teacher ratios.

# %%
summary_stats = boston.describe()
print(summary_stats[['crim', 'tax', 'ptratio']])
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %%
Boston.boxplot(column='crim',vert=False)
plt.show()
Boston.boxplot(column='tax',vert=False)
plt.show()
Boston.boxplot(column='ptratio',vert=False)
# Out:
# <Axes: >

# %% [markdown]
# ##part e (reference 2)

# %%
# (e)
# 查看犯罪率、稅率、師生比的範圍
print(boston[['crim', 'tax', 'ptratio']].describe())

# 查看犯罪率、稅率、師生比的描述性統計
print(boston[['crim', 'tax', 'ptratio']].describe())

# 繪製犯罪率、稅率和師生比的直方圖
boston[['crim', 'tax', 'ptratio']].hist(bins=30, figsize=(12, 8))
plt.tight_layout()
plt.show()
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %% [markdown]
# Comment:
#
# The crime rate ranges from 0.006 to 88.976. Most suburbs have relatively low crime rates, but there are a few suburbs with particularly high crime rates, indicating that these areas might be less safe.
#
# 犯罪率: 範圍廣，從 0.006 到 88.976。大多數郊區的犯罪率較低，但有幾個郊區的犯罪率特別高。這些高犯罪率的郊區可能位於較不安全的社區。
# __________________________________________________________
# The tax rate ranges from 187 to 711. While the majority of suburbs have moderate tax rates, there are a few that have significantly higher rates. This could be due to the level of public services, infrastructure development, or fiscal policies in those areas.
#
# 稅率: 稅率的範圍從 187 到 711。大部分郊區的稅率集中在中低範圍, 但有些郊區的稅率顯著較高, 這可能與當地基礎設施的開發或政府的財政政策有關。
# __________________________________________________________
# The pupil-teacher ratio ranges from 12.6 to 22.0. Most suburbs have a ratio around 18, but some suburbs have higher ratios, which may indicate fewer educational resources and larger class sizes.
#
# 師生比: 師生比的範圍從 12.6 到 22.0。大部分郊區的師生比在中等範圍( 約18 ), 但有些郊區的師生比例明顯較高，這可能意味著當地學校的資源較為有限。
# __________________________________________________________
# Conclusion: There is considerable variability in crime rates, tax rates, and pupil-teacher ratios across the suburbs of Boston. Some suburbs have particularly high crime rates, while others show high tax rates or pupil-teacher ratios, reflecting the diversity in socio-economic conditions, public services, and education resources.
#
# 波士頓郊區的犯罪率、稅率和師生比的範圍都有所不同。一些郊區犯罪率較高，而其他郊區則稅率或師生比較高，這可能反映了當地經濟水平、教育資源和治安狀況的不同。

# %% [markdown]
# ##part e (reference 3)

# %%
print("Suburbs with high crime rates:")
print(boston[boston.crim > boston.crim.quantile(0.95)])

print("\nSuburbs with high tax rates:")
print(boston[boston.tax > boston.tax.quantile(0.9)])

print("\nSuburbs with high pupil-teacher ratios:")
print(boston[boston.ptratio > boston.ptratio.quantile(0.9)])

for column in boston.columns:
  print("\nRange of predictor", column + ":")
  print("Minimum:", boston[column].min())
  print("Maximum:", boston[column].max())
# Out:
# Suburbs with high crime rates:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 374  18.4982  0.0   18.1     0  0.668  4.138  100.0  1.1370   24  666
# 375  19.6091  0.0   18.1     0  0.671  7.313   97.9  1.3163   24  666
# 378  23.6482  0.0   18.1     0  0.671  6.380   96.2  1.3861   24  666
# 379  17.8667  0.0   18.1     0  0.671  6.223  100.0  1.3861   24  666
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 381  15.8744  0.0   18.1     0  0.671  6.545   99.1  1.5192   24  666
# 384  20.0849  0.0   18.1     0  0.700  4.368   91.2  1.4395   24  666
# 385  16.8118  0.0   18.1     0  0.700  5.277   98.1  1.4261   24  666
# 386  24.3938  0.0   18.1     0  0.700  4.652  100.0  1.4672   24  666
# 387  22.5971  0.0   18.1     0  0.700  5.000   89.5  1.5184   24  666
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 400  25.0461  0.0   18.1     0  0.693  5.987  100.0  1.5888   24  666
# ...

# %% [markdown]
# #part f
# To count the number of suburbs that bound the Charles River, I use the sum() function.

# %%
print(f"Number of suburbs that bound the Charles River: {(boston['chas']==1).sum()}")
# Out:
# Number of suburbs that bound the Charles River: 35

# %% [markdown]
# #part g
# To calculate the median of pupil-teacher ratio I use the median() method.

# %%
print(f"Median of pupil-teacher ratio: {boston['ptratio'].median()}")
# Out:
# Median of pupil-teacher ratio: 19.05

# %% [markdown]
# #part h (reference 1)
# To find the suburb with the lowest median value of owner-occupied homes, I use the idxmin() function.
#
# According to the results, these are some features of other predictors of the suburb with the lowest median value of owner-occupied homes. First, this suburb has 0% of residential land zoned for lots over 25,000 sq.ft, a small residential land zone. Second, the proportion of non-retail business acres is at the upper quartile of overall data. Third, it is not near river bounds. Fourth, the nitrogen oxide concentration is higher than the overall of upper quartile. Fifth, the average number of rooms per dwelling is below the lower quartile. Six, 100% of owner-occupied units were built prior to 1940. Seven, it is nearly the closest to employment centres. Eight, it has the highest accessibility to radial highways, which may also explain the reason for high crime rates. Nine, It has a high tax rate as an upper quartile. Ten, the pupil-teacher ratios are at the upper quartile, too. Last, It is higher than the upper quartile in the percentage of lower status of the population.
#
# All the features may mean that this suburb may be mainly for workers and the poor; thus, people may tend to buy property at other places or only buy property in this suburb for rental profit, both causing the lowest median value of owner-occupied homes.

# %%
lowest_medv_suburb = boston['medv'].idxmin()
print(f"Suburb with the lowest median value of owner-occupied homes: {lowest_medv_suburb}")

lowest_medv_values = boston.loc[lowest_medv_suburb]
print(lowest_medv_values)

#compare values to the overall ranges for other predictors
summary_stats
# Out:
# Suburb with the lowest median value of owner-occupied homes: 398
# crim        38.3518
# zn           0.0000
# indus       18.1000
# chas         0.0000
# nox          0.6930
# rm           5.4530
# age        100.0000
# dis          1.4896
# rad         24.0000
# tax        666.0000
# ptratio     20.2000
# lstat       30.5900
# medv         5.0000
# Name: 398, dtype: float64
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# ...

# %% [markdown]
# ## part h (reference 2)

# %%
print(f"The suburb of Boston with the lowest median value of owner-occupied homes is {boston['medv'].idxmin()} which its value is {boston.loc[boston['medv'].idxmin()]['medv']}.")
# Out:
# The suburb of Boston with the lowest median value of owner-occupied homes is 398 which its value is 5.0.

# %%
min_medv_suburb = boston.loc[boston['medv'].idxmin()]
print(f"The other predictors for that suburb are:")
print(min_medv_suburb)
# Out:
# The other predictors for that suburb are:
# crim        38.3518
# zn           0.0000
# indus       18.1000
# chas         0.0000
# nox          0.6930
# rm           5.4530
# age        100.0000
# dis          1.4896
# rad         24.0000
# tax        666.0000
# ptratio     20.2000
# lstat       30.5900
# medv         5.0000
# Name: 398, dtype: float64

# %%
print(boston.describe())
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# Finding:
#
# 1. **Crime Rate (crim)**:
# - Suburb / Overall: 38.3518 / 3.6135
# - Comment: The suburb with the lowest median house value has an exceptionally high crime rate (38.35), which is well above the 75th percentile (3.68) and approaches the maximum crime rate of the dataset (88.98). This high crime rate likely contributes to the low property values in this area.
#
# 2. **Nitrogen Oxides (nox)**:
# - Suburb / Overall: 0.6930 / 0.5547
# - Comment: The nitrogen oxides concentration in this suburb is above the overall mean and lies between the 75th percentile (0.624) and the maximum value (0.871). This higher level of pollution might indicate industrial activity, which can lower the attractiveness of the suburb.
#
# 3. **Number of Rooms (rm)**:
# - Suburb / Overall: 5.4530 / 6.2846
# - Comment: The average number of rooms per dwelling in this suburb is 5.45, which is below the overall mean and the 25th percentile. Smaller homes with fewer rooms may suggest lower quality or less spacious housing, potentially contributing to the lower median value.
#
# 4. **Tax Rate (tax)**:
# - Suburb / Overall: 666.0000 / 408.2372
# - Comment: The tax rate for this suburb is at the 75th percentile and considerably higher than the mean. A higher tax rate in this area, combined with other negative factors, may further burden residents and reduce property demand.
#
# 5. **Pupil-Teacher Ratio (ptratio)**:
# - Suburb / Overall: 20.2000 / 18.4555
# - Comment: The pupil-teacher ratio in this suburb is above the mean (18.46) and equal to the 75th percentile. A higher pupil-teacher ratio often reflects crowded schools, which can negatively affect education quality and housing demand.
#
# 6. **Lower Status Population (lstat)**:
# - Suburb / Overall: 30.5900 / 12.6531
# - Comment: This suburb has a significantly higher percentage of lower-status population compared to the overall mean. This value is much higher than the 75th percentile and indicates a high level of economic disadvantage, which likely contributes to the low median house values.
#
# 7. **Median Value of Owner-Occupied Homes (medv)**:
# - Suburb / Overall: 5.0000 / 22.5328
# - Comment: The suburb has the lowest possible median house value in the dataset. This is far below the mean and the 25th percentile, indicating that housing in this area is substantially less valuable compared to most other suburbs.
#
# Conclusion:
#
# The suburb with the lowest median house value is characterized by extremely high crime rates, a high concentration of nitrogen oxides (pollution), fewer rooms per dwelling, a high tax rate, a high pupil-teacher ratio, and a high percentage of lower-status population.
#
# These factors suggest that this suburb faces significant economic, environmental, and social challenges, all of which contribute to the very low property values in the area.

# %% [markdown]
# #part i (reference 1)
# To count the number of suburbs that average more than seven or eight rooms per dwelling, I use conditional statements.
#
# According to the results, these suburbs may be for the middle and high class. First, these suburbs have 20% or 95% of residential land zoned for lots over 25,000 sq.ft, not small and big residential land zones. Second, the proportion of non-retail business acres is mostly below 10%. Third, some of these suburbs are near river bounds. Fourth, the nitrogen oxide concentration for them is lower than the overall. Fifth, a mean of 71.54% of owner-occupied units were built prior to 1940, lower than the overall median. Six, it is not that near to employment centres. Seven, the pupil-teacher ratios are lower compared to overall data. Last, It is lower in the percentage of the lower status of the population in these suburbs.
#
# All of the above suggests that these suburbs, which have an average of more than eight rooms per dwelling, mainly have middle-class or upper-class citizens.

# %%
suburbs_above_7_rooms = (boston['rm'] > 7).sum()
suburbs_above_8_rooms = (boston['rm'] > 8).sum()

print(f"Suburbs with more than 7 rooms per dwelling: {suburbs_above_7_rooms}")
print(f"Suburbs with more than 8 rooms per dwelling: {suburbs_above_8_rooms}")
# Out:
# Suburbs with more than 7 rooms per dwelling: 64
# Suburbs with more than 8 rooms per dwelling: 13

# %%
suburbs_above_8_rooms = boston[boston['rm'] > 8]
suburbs_above_8_rooms.describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...

# %% [markdown]
# ## part i (reference 2)

# %%
print(f"{boston[boston['rm'] > 7].shape[0]} suburbs average more than seven rooms per dwelling.")
print(f"{boston[boston['rm'] > 8].shape[0]} suburbs average more than eight rooms per dwelling.")
# Out:
# 64 suburbs average more than seven rooms per dwelling.
# 13 suburbs average more than eight rooms per dwelling.

# %%
rm_greater_than_8 = boston[boston['rm'] > 8]
print(rm_greater_than_8.describe())
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...

# %%
print(boston.describe())
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# Finding:
#
# 1. **Crime Rate (crim)**:
#    - **Suburbs with rm > 8**: Mean = 0.719, Max = 3.474
#    - **Overall Suburbs**: Mean = 3.614, Max = 88.976
#    - **Comparison**: Suburbs with more than 8 rooms per dwelling tend to have a much lower crime rate on average compared to the overall average. The maximum crime rate in these suburbs is also significantly lower than the overall maximum.
#
# 2. **Zoning (zn)**:
#    - **Suburbs with rm > 8**: Mean = 13.62, Max = 95.00
#    - **Overall Suburbs**: Mean = 11.36, Max = 100.00
#    - **Comparison**: The proportion of residential land zoned for large lots is slightly higher in the `rm > 8` group compared to the overall suburbs. This reflects a trend that homes with more rooms are often in areas with more residential zoning.
#
# 3. **Non-Retail Business Land (indus)**:
#    - **Suburbs with rm > 8**: Mean = 7.08, Max = 19.58
#    - **Overall Suburbs**: Mean = 11.14, Max = 27.74
#    - **Comparison**: The proportion of non-retail business land in suburbs with larger homes is lower on average, indicating that these areas are more residential and less industrialized than the overall suburbs.
#
# 4. **Nitrogen Oxides Concentration (nox)**:
#    - **Suburbs with rm > 8**: Mean = 0.539, Max = 0.718
#    - **Overall Suburbs**: Mean = 0.555, Max = 0.871
#    - **Comparison**: Suburbs with larger homes have slightly lower air pollution levels on average, suggesting a cleaner environment in these areas.
#
# 5. **Average Number of Rooms (rm)**:
#    - **Suburbs with rm > 8**: Mean = 8.35, Max = 8.78
#    - **Overall Suburbs**: Mean = 6.28, Max = 8.78
#    - **Comparison**: Naturally, suburbs with more than 8 rooms per dwelling have a much higher average number of rooms than the overall suburbs.
#
# 6. **Age of Homes (age)**:
#    - **Suburbs with rm > 8**: Mean = 71.54, Max = 93.90
#    - **Overall Suburbs**: Mean = 68.57, Max = 100.00
#    - **Comparison**: Homes in the `rm > 8` group are slightly older on average compared to the overall suburbs, but the difference is not substantial.
#
# 7. **Distance to Employment Centers (dis)**:
#    - **Suburbs with rm > 8**: Mean = 3.43, Max = 8.91
#    - **Overall Suburbs**: Mean = 3.80, Max = 12.13
#    - **Comparison**: These suburbs tend to be slightly closer to employment centers on average, though there is a wide range of distances in both groups.
#
# 8. **Accessibility to Radial Highways (rad)**:
#    - **Suburbs with rm > 8**: Mean = 7.46, Max = 24.00
#    - **Overall Suburbs**: Mean = 9.55, Max = 24.00
#    - **Comparison**: Suburbs with larger homes have slightly less accessibility to radial highways on average, indicating they may be located in more secluded or suburban areas.
#
# 9. **Property Tax Rate (tax)**:
#    - **Suburbs with rm > 8**: Mean = 325.08, Max = 666.00
#    - **Overall Suburbs**: Mean = 408.24, Max = 711.00
#    - **Comparison**: Property tax rates are generally lower in the `rm > 8` group compared to the overall suburbs, though some suburbs with larger homes have high taxes.
#
# 10. **Pupil-Teacher Ratio (ptratio)**:
#    - **Suburbs with rm > 8**: Mean = 16.36, Max = 20.20
#    - **Overall Suburbs**: Mean = 18.46, Max = 22.00
#    - **Comparison**: The pupil-teacher ratio is lower in these suburbs, suggesting that schools in areas with larger homes may have smaller class sizes and better educational resources.
#
# 11. **Lower Status Population (lstat)**:
#    - **Suburbs with rm > 8**: Mean = 4.31, Max = 7.44
#    - **Overall Suburbs**: Mean = 12.65, Max = 37.97
#    - **Comparison**: The percentage of lower-status population is much lower in the `rm > 8` group, indicating that these suburbs are generally more affluent.
#
# 12. **Median Value of Owner-Occupied Homes (medv)**:
#    - **Suburbs with rm > 8**: Mean = 44.20, Max = 50.00
#    - **Overall Suburbs**: Mean = 22.53, Max = 50.00
#    - **Comparison**: The median value of homes in these suburbs is significantly higher than the overall average. Many of the suburbs with more than 8 rooms have homes at the maximum recorded value of $50,000.
#
# Conclusion:
#
# Suburbs with more than 8 rooms per dwelling are characterized by lower crime rates, lower pollution levels, and a more affluent population, as indicated by the lower percentage of lower-status individuals (lstat).
# They tend to have lower tax rates and better access to educational resources (lower pupil-teacher ratios), making them more desirable places to live.
#
# These factors contribute to the significantly higher median home values in these areas. Overall, these suburbs represent more affluent, suburban communities compared to the average across all suburbs.

# %% [markdown]
# #[Portfolio Management]
#
# 1. Find the mean and standard deviation of returns of these five stocks.
# 2. Plot the mean and risk (standard deviation) for these five returns using red starts in the 2-dimensional plane.
# 3. Randomly selected weights so that each weight is nonnegative and sums up to one. Print the random weight, the mean and standard deviation of the portfolio.
# 4. Repeat c) for 1000 times, and plot the mean and standard deviation for these artificial portfolios using blue points in the 2-dimensional plane in b).
# 5. Draw the efficiency frontier in the figure of b), assuming that no short sales are allowed.
# 6. Check if the efficiency frontier in e) is the envelope line of the blue points in d).

# %% [markdown]
# ##Reference 1 (Optimization-based method):
# - Approach: It explicitly uses optimization to calculate the portfolio that minimizes risk (standard deviation) for a given target return, ensuring that the efficient frontier is computed accurately by solving the portfolio optimization problem for each target return.
# - Advantage: This method is more precise because it computes the efficient frontier directly using mathematical optimization. It guarantees the lowest risk for each return level by solving for optimal portfolio weights.
# - Limitation: It can be computationally intensive, especially for large portfolios, as it requires solving an optimization problem for each point on the frontier.
#
# ##Reference 2 (Sorting-based method):
# - Approach: It relies on a pre-generated set of random portfolios. The code then selects the portfolios with the minimum risk (standard deviation) for each level of return.
# - Advantage: This method is simple and quick if you already have a large set of portfolios available. It’s useful for visualizing the efficient frontier based on sampled portfolios.
# - Limitation: Since it only considers portfolios from a pre-generated set, it may not guarantee the "true" minimum-risk portfolios for each level of return, especially if the pre-generated portfolios are not exhaustive.
#
# ##In summary:
# Both methods are correct, but Reference 1 provides a more precise calculation of the efficient frontier by explicitly minimizing risk for each return target. Reference 2 is a valid approach when you have a predefined set of portfolios, but it might be less accurate since it relies on pre-generated data rather than direct optimization.

# %% [markdown]
# ##Reference 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# 1: Load the dataset
df = pd.read_csv('/content/sample_data/Stocks_ClosePrice.csv')
returns = df[['FB.1', 'GOOG.1', 'NFLX.1', 'AMZN.1', 'AAPL.1']].dropna()
returns = returns.astype(float)

mean_returns = returns.mean()
std_returns = returns.std()

print("Mean Returns:\n", mean_returns)
print("Standard Deviation of Returns:\n", std_returns)

# Step 2: Plot mean vs standard deviation of these five returns using red stars
plt.figure(figsize=(10, 6))
plt.scatter(std_returns, mean_returns, color='red', marker='*', label='Individual Stocks')
for i, stock in enumerate(returns.columns):
    plt.annotate(stock, (std_returns[i], mean_returns[i]), textcoords="offset points", xytext=(5, 5), ha='center')

plt.xlabel('Risk (Standard Deviation)')
plt.ylabel('Mean Return')
plt.title('Mean vs Risk (Standard Deviation) of Stocks')

# Step 3: Randomly selected portfolio weights (non-negative and sum to 1)
def random_weights(n):
    weights = np.random.rand(n)
    return weights / np.sum(weights)

weights = random_weights(len(mean_returns))
portfolio_mean = np.dot(weights, mean_returns)
portfolio_std = np.sqrt(np.dot(weights.T, np.dot(returns.cov(), weights)))

print("\nRandom Portfolio Weights:", weights)
print("Portfolio Mean Return:", portfolio_mean)
print("Portfolio Standard Deviation:", portfolio_std)

# Step 4: Simulate 1000 portfolios
num_portfolios = 1000
port_means = []
port_stds = []

for _ in range(num_portfolios):
    weights = random_weights(len(mean_returns))
    port_mean = np.dot(weights, mean_returns)
    port_std = np.sqrt(np.dot(weights.T, np.dot(returns.cov(), weights)))

    port_means.append(port_mean)
    port_stds.append(port_std)

# Step 5: Plot the simulated portfolios on the same figure (blue points)
plt.scatter(port_stds, port_means, color='blue', marker='o', s=10, label='Simulated Portfolios')
plt.legend()

# Step 6: Efficiency frontier (no short sales)
def portfolio_stats(weights):
    port_mean = np.dot(weights, mean_returns)
    port_std = np.sqrt(np.dot(weights.T, np.dot(returns.cov(), weights)))
    return np.array([port_std, port_mean])

def minimize_risk(weights):
    return portfolio_stats(weights)[0]

def efficient_frontier(target_return):
    cons = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1},
            {'type': 'eq', 'fun': lambda x: np.dot(x, mean_returns) - target_return})
    bounds = [(0, 1) for _ in range(len(mean_returns))]
    result = minimize(minimize_risk, len(mean_returns) * [1. / len(mean_returns)], method='SLSQP', bounds=bounds, constraints=cons)
    return result

target_returns = np.linspace(min(mean_returns), max(mean_returns), 100)
frontier_stds = []

for target in target_returns:
    res = efficient_frontier(target)
    frontier_stds.append(portfolio_stats(res.x)[0])

plt.plot(frontier_stds, target_returns, color='green', linestyle='--', label='Efficient Frontier')
plt.legend()

plt.show()

# 6
print("\n Yes, the efficiency frontier appears as the lower envelope of the blue points in the plot.")
# Out:
# Mean Returns:
#  FB.1      0.000555
# GOOG.1    0.000189
# NFLX.1   -0.001250
# AMZN.1   -0.000302
# AAPL.1   -0.000056
# dtype: float64
# Standard Deviation of Returns:
#  FB.1      0.020943
# GOOG.1    0.018474
# NFLX.1    0.027119
# AMZN.1    0.022313
# AAPL.1    0.020421
# dtype: float64
#
# Random Portfolio Weights: [0.2878973  0.17350771 0.23970886 0.06538159 0.23350454]
# Portfolio Mean Return: -0.0001398565171767392
# Portfolio Standard Deviation: 0.018312779943541142
# <ipython-input-32-00231fa08924>:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(stock, (std_returns[i], mean_returns[i]), textcoords="offset points", xytext=(5, 5), ha='center')
#  Yes, the efficiency frontier appears as the lower envelope of the blue points in the plot.

# %% [markdown]
# ##Reference 2

# %%
# To find the efficient frontier, we focus on portfolios with the lowest standard deviation for a given mean return

# Convert lists to arrays for easier processing
portfolio_means = np.array(portfolio_means)
portfolio_stds = np.array(portfolio_stds)

# Sort portfolios by mean return and find the minimum std for each unique mean return
sorted_indices = np.argsort(portfolio_means)
sorted_means = portfolio_means[sorted_indices]
sorted_stds = portfolio_stds[sorted_indices]

# Calculate the efficiency frontier by filtering portfolios with minimum std for a given mean return
efficient_frontier_means = []
efficient_frontier_stds = []

for i in range(len(sorted_means)):
    if i == 0 or sorted_stds[i] < min(efficient_frontier_stds):
        efficient_frontier_means.append(sorted_means[i])
        efficient_frontier_stds.append(sorted_stds[i])

# Plot the efficient frontier
plt.figure(figsize=(8, 6))
plt.scatter(mean_returns, std_returns, color='red', marker='*', s=200, label='Individual Stocks')
plt.scatter(portfolio_means, portfolio_stds, color='blue', alpha=0.5, label='Random Portfolios')
plt.plot(efficient_frontier_means, efficient_frontier_stds, color='green', linewidth=2, label='Efficient Frontier')

# Add labels and title
plt.title('Mean vs. Risk (Standard Deviation) with Efficient Frontier')
plt.xlabel('Mean Return')
plt.ylabel('Risk (Standard Deviation)')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
