# %% [markdown]
# # (a) Write a function, Power(), that prints out the result of raising 2 to the 3rd power. In other words, your function should compute 2**3 and print out the results.

# %%
def Power():
    print(2 ** 3)

Power()
# Out:
# 8

# %% [markdown]
# # (b) Create a new function, Power2(), that allows you to pass any two numbers, x and a, and prints out the value of x**a. You can do this by beginning your function with the line "def Power2(x, a)" You should be able to call your function by entering, for instance,Power2(3, 8) on the commandline. This should output the value of 38, namely,6, 561.

# %%
def Power2(x, a):
    print(x ** a)

Power2(3, 8)
# Out:
# 6561

# %% [markdown]
# # (c) Using the Power2() function that you just wrote, compute 10**3, 8**17, and 131**3.

# %%
Power2(10,3),Power2(8,17),Power2(131,3)
# Out:
# 1000
# 2251799813685248
# 2248091
# (None, None, None)

# %% [markdown]
# # (d) Now create a new function, Power3(), that actually returns the result x**a as a Python object, rather than simply printing it to the screen. That is, if you store the value x**a in an object called "result" within your function, then you can simply return this result, using the following line:return result

# %%
def Power3(x, a):
    result = x ** a
    return result


result = Power3(2, 3)  
print(result)
# Out:
# 8

# %% [markdown]
# # (e) Now using the Power3() function, create a plot of f(x)=x2.The x-axis should display a range of integers from 1 to 10, and the y-axis should display x2. Label the axes appropriately, and use an appropriate title for the figure. Consider displaying either the x-axis, the y-axis, or both on the log-scale. You can do this by using the ax.set_xscale() and ax.set_yscale() methods of .set_xscale() the axes you are plotting to  .set_yscale()

# %%
import matplotlib.pyplot as plt
import numpy as np


x_values = np.arange(1, 11)
y_values = [Power3(x, 2) for x in x_values]  #f(x) = x^2


plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values, marker='o')
plt.xlabel('x')
plt.ylabel('x^2')
plt.title('Plot of f(x)')


plt.xscale('linear')
plt.yscale('log')
plt.show()

# %% [markdown]
# # (f) Create a function, PlotPower(), that allows you to create a plot of x against x**a for a fixed a and a sequence of values of x. For instance, if you call PlotPower(np.arange(1, 11), 3) then a plot should be created with an x-axis taking on values 1, 2,...,10, and a y-axis taking on values 1**3,2**3,...,10**3

# %%
def PlotPower(x, a):
    y = [Power3(val, a) for val in x]
    

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, marker='o')
    plt.xlabel('x')
    plt.ylabel(f'x^{a}')
    plt.title(f'Plot of x^{a}')
    plt.xscale('linear')
    plt.yscale('log')
    plt.show()


import numpy as np
PlotPower(np.arange(1, 11), 3)
