# %% [markdown]
# ## Chapter 4. Question 15
# This problem involves writing functions.

# %% [markdown]
# ### Part (a)
# (a) Write a function, `Power()`, that prints out the result of raising 2 to the 3rd power. In other words, your function should compute 23 and print out the results.
# Hint: Recall that `x**a` raises `x` to the power `a`. Use the `print()` function to display the result.

# %%
import numpy as np
import matplotlib.pyplot as plt

# (a) Function to print 2 raised to the 3rd power
def Power():
    result = 2 ** 3
    print(result)

# %% [markdown]
# ### Part (b)
# (b) Create a new function, `Power2()`, that allows you to pass any two numbers, `x` and `a`, and prints out the value of `x**a`. You can do this by beginning your function with the line
# `def Power2(x, a):`
# You should be able to call your function by entering, for instance,
# `Power2(3, 8)`
# on the command line. This should output the value of 38, namely, 6, 561.

# %%
# (b) Function to print x raised to the power a
def Power2(x, a):
    print(x ** a)

# %% [markdown]
# ### Part (c)
# (c) Using the `Power2()` function that you just wrote, compute 103, 817, and 1313.

# %%
# (c) Compute 10^3, 8^1, and 13^3 using Power2()
Power2(10, 3)  # Output: 1000
Power2(8, 1)   # Output: 8
Power2(13, 3)  # Output: 2197
# Out:
# 1000
# 8
# 2197

# %% [markdown]
# ### Part (d)
# (d) Now create a new function, `Power3()`, that actually returns the
# result `x**a` as a `Python` object, rather than simply printing it
# to the screen. That is, if you store the value `x**a` in an object
# called result within your function, then you can simply `return` this result, using the following line:
# `return result`
# Note that the line above should be the last line in your function, and it should be indented 4 spaces.

# %%
# (d) Function to return x raised to the power a
def Power3(x, a):
    result = x ** a
    return result

# %% [markdown]
# ### Part (e)
# (e) Now using the `Power3()` function, create a plot of f(x) = x2. The x-axis should display a range of integers from 1 to 10, and the y-axis should display x2. Label the axes appropriately, and use an appropriate title for the figure. Consider displaying either the x-axis, the y-axis, or both on the log-scale. You can do this by using the `ax.set_xscale()` and `ax.set_yscale()` methods of the axes you are plotting to.

# %%
# (e) Function to plot f(x) = x^2
def plot_function():
    x_values = np.arange(1, 11)
    y_values = Power3(x_values, 2)
    
    plt.figure(figsize=(8, 5))
    plt.plot(x_values, y_values, label='$f(x) = x^2$', marker='o')
    plt.xlabel('x')
    plt.ylabel('$f(x)$')
    plt.title('Plot of $f(x) = x^2$')
    plt.grid()
    plt.yscale('linear')  # Change to 'log' if log scale is desired
    plt.xticks(np.arange(1, 11))
    plt.legend()
    plt.show()

# %% [markdown]
# ### Part (f)
# (f) Create a function, `PlotPower()`, that allows you to create a plot of `x` against `x**a` for a fixed `a` and a sequence of values of `x`. For instance, if you call
# `PlotPower(np.arange(1, 11), 3)`
# then a plot should be created with an x-axis taking on values 1,2,...,10, and a y-axis taking on values 13,23,...,103.

# %%
# (f) Function to plot x against x^a for a fixed a
def PlotPower(x_values, a):
    y_values = x_values ** a
    plt.figure(figsize=(8, 5))
    plt.plot(x_values, y_values, label=f'$y = x^{a}$', marker='o')
    plt.xlabel('x')
    plt.ylabel(f'$y$')
    plt.title(f'Plot of $y = x^{a}$ for a={a}')
    plt.grid()
    plt.xticks(np.arange(min(x_values), max(x_values) + 1))
    plt.legend()
    plt.show()

# Example usage of the functions
Power()  # Part (a)
Power2(3, 8)  # Part (b)
plot_function()  # Part (e)
PlotPower(np.arange(1, 11), 3)  # Part (f)
# Out:
# 8
# 6561
