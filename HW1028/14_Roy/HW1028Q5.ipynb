# %% [markdown]
# ## 15. This problem involves writing functions.
# ### (a) Write a function, Power(), that prints out the result of raising 2 to the 3rd power. In other words, your function should compute 23 and print out the results.

# %%
def Power():
    result = 2 ** 3
    print(result)

# Call the function to test
Power()
# Out:
# 8

# %% [markdown]
# ### (b) Create a new function, Power2(), that allows you to pass any two numbers, x and a, and prints out the value of x**a. You can do this by beginning your function with the line

# %%
def Power2(x, a):
    result = x ** a
    print(result)

# Example call to test the function
Power2(3, 8)
# Out:
# 6561

# %% [markdown]
# ### (c) Using the Power2() function that you just wrote, compute 103, 817, and 1313.

# %%
# Define the Power2 function
def Power2(x, a):
    result = x ** a
    print(result)

# Compute the required values
Power2(10, 3)   # 10^3
Power2(8, 17)   # 8^17
Power2(13, 13)  # 13^13
# Out:
# 1000
# 2251799813685248
# 302875106592253

# %% [markdown]
# ### (d) Now create a new function, Power3(), that actually returns the result x**a as a Python object, rather than simply printing it to the screen.

# %%
def Power3(x, a):
    result = x ** a
    return result

# Example calls to test the function
print(Power3(10, 3))   # Should return 1000
print(Power3(8, 17))   # Should return 2251799813685248
print(Power3(13, 13))  # Should return 302875106592253
# Out:
# 1000
# 2251799813685248
# 302875106592253

# %% [markdown]
# ### (e) Now using the Power3() function, create a plot of f(x) = x2. The x-axis should display a range of integers from 1 to 10, and the y-axis should display x2. Label the axes appropriately, and use an appropriate title for the figure. Consider displaying either the x-axis, the y-axis, or both on the log-scale. You can do this by using the ax.set_xscale() and ax.set_yscale() methods of the axes you are plotting to.

# %%
import matplotlib.pyplot as plt

# Define the Power3 function
def Power3(x, a):
    result = x ** a
    return result

# Generate data for plotting f(x) = x^2
x_values = range(1, 11)
y_values = [Power3(x, 2) for x in x_values]

# Create the plot
fig, ax = plt.subplots()
ax.plot(x_values, y_values, marker='o', linestyle='-', color='b')

# Set labels and title
ax.set_xlabel("x")
ax.set_ylabel("f(x) = x^2")
ax.set_title("Plot of f(x) = x^2 with Log-Scale on Y-Axis")

# Set y-axis to log-scale
ax.set_yscale("log")

# Display the plot
plt.show()

# %% [markdown]
# ###(f) Create a function, PlotPower(), that allows you to create a plot of x against x**a for a fixed a and a sequence of values of x.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the Power3 function
def Power3(x, a):
    result = x ** a
    return result

# Define the PlotPower function
def PlotPower(x_values, a):
    y_values = [Power3(x, a) for x in x_values]

    # Create the plot
    fig, ax = plt.subplots()
    ax.plot(x_values, y_values, marker='o', linestyle='-', color='b')

    # Set labels and title
    ax.set_xlabel("x")
    ax.set_ylabel(f"f(x) = x^{a}")
    ax.set_title(f"Plot of f(x) = x^{a}")

    # Display the plot
    plt.show()

# Example call to test the function
PlotPower(np.arange(1, 11), 3)
