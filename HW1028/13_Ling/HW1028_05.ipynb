# %% [markdown]
# # Ch04_Q15

# %% [markdown]
# ## This problem involves writing functions.

# %% [markdown]
# ##  (a) Write a function, Power(), that prints out the result of raising 2 to the 3rd power. In other words, your function should compute 2^3 and print out the results.
# ##  Hint: Recall that x**a raises x to the power a. Use the print() function to display the result.

# %%
def Power():
    result = 2 ** 3  # Calculate 2 raised to the power of 3
    print(result)

Power()
# Out:
# 8

# %% [markdown]
# ## (b)  Create a new function, Power2(), that allows you to pass any two numbers, x and a, and prints out the value of x**a. You can do this by beginning your function with the line
# ### def Power2(x, a):
# ## You should be able to call your function by entering, for instance,
# ### Power2(3, 8)
# ## on the command line. This should output the value of 3^8, namely, 6, 561.

# %%
def Power2(x, a):
    result = x ** a  # Calculate 2 raised to the power of 3
    print(result)

Power2(3, 8)
# Out:
# 6561

# %% [markdown]
# ## (c) Using the Power2() function that you just wrote, compute 10^3, 8^17, and 131^3.

# %%
Power2(10, 3)  # Calculate 10 raised to the power of 3
Power2(8, 17)  # Calculate 8 raised to the power of 17
Power2(131, 3)  # Calculate 131 raised to the power of 3
# Out:
# 1000
# 2251799813685248
# 2248091

# %% [markdown]
# ## (d) Now create a new function, Power3(), that actually returns the result x**a as a Python object, rather than simply printing it to the screen. That is, if you store the value in an object called result within your function, then you can simply return  this result, using the following line:
# ### return result
# ## Note that the line above should be the last line in your function, and it should be indented 4 spaces.

# %%
def Power3(x, a):
    result = x ** a
    return result

result1 = Power3(10, 3)
result2 = Power3(8, 17)
result3 = Power3(131, 3)

print(result1)
print(result2)
print(result3)
# Out:
# 1000
# 2251799813685248
# 2248091

# %% [markdown]
# ## (e) Now using the Power3() function, create a plot of f(x) = x^2. The x-axis should display a range of integers from 1 to 10, and the y-axis should display x^2. Label the axes appropriately, and use an appropriate title for the fgure. Consider displaying either the x-axis, the y-axis, or both on the log-scale. You can do this by using the ax.set_xscale() and ax.set_yscale() methods of the axes you are plotting to.

# %%
import matplotlib.pyplot as plt

# Function to compute power
def Power3(x, a):
    result = x ** a
    return result

# Define the range of x values
x_values = range(1, 11)  # integers from 1 to 10
y_values = [Power3(x, 2) for x in x_values]  # Compute x^2 for each x

# Create the plot
fig, ax = plt.subplots()
ax.plot(x_values, y_values, marker='o')

# Set labels and title
ax.set_xlabel('x values')
ax.set_ylabel('f(x) = x^2')
ax.set_title('Plot of f(x) = x^2')

# Optionally, set the y-axis to a log scale
ax.set_yscale('log')

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ## (f)  Create a function, PlotPower(), that allows you to create a plot of x against x**a for a fxed a and a sequence of values of x. For instance, if you call
# ### PlotPower(np.arange(1, 11), 3)
# ## then a plot should be created with an x-axis taking on values1, 2,..., 10, and a y-axis taking on values 1^3, 2^3,..., 10^3.

# %%
import numpy as np
import matplotlib.pyplot as plt

def Power3(x, a):
    """Returns x raised to the power of a."""
    return x ** a

def PlotPower(x_values, a):
    """Plots x against x raised to the power of a."""
    y_values = [Power3(x, a) for x in x_values]  # Compute x^a for each x

    # Create the plot
    fig, ax = plt.subplots()
    ax.plot(x_values, y_values, marker='o', label=f'x^{a}')

    # Set labels and title
    ax.set_xlabel('x values')
    ax.set_ylabel(f'f(x) = x^{a}')
    ax.set_title(f'Plot of f(x) = x^{a}')

    # Optionally, you can set log scale for the y-axis
    # ax.set_yscale('log')

    ax.grid(True)
    ax.legend()  # Show the legend
    plt.show()

# Example usage
PlotPower(np.arange(1, 11), 3)  # Create a plot for x^3
