# %%
###Q2
###(a)訓練 RSS：當λ增加時，模型的迴歸係數會被收縮，模型的複雜度下降，這會增加模型的偏差。隨著λ
###增加，訓練 RSS 會逐漸增加，因為模型擬合的能力降低。所以答案是 iii. 持續增加。

###(b)測試 RSS：在λ小的情況下，模型可以過度擬合訓練數據，導致較高的測試 RSS。隨著λ增加，測試 RSS 會先減少（因為模型變得更平滑），但當
###λλ過大時，模型的擬合能力不足，測試 RSS 又會開始增加。所以答案是 ii. 一開始下降，之後最終開始增加，呈現 U 型。

###(c)變異數：隨著λ增加，模型的係數被收縮，模型的靈活性下降，變異數也會持續減少。所以答案是 iv. 持續減少。

###(d)（平方）偏差：當λ增加時，模型變得更平滑，但同時偏差會增大。隨著λ增加，偏差會持續增加。因此答案是 iii. 持續增加

###(e) 不可化簡誤差：這部分誤差是數據中的隨機性，與模型無關，因此答案是 v. 保持不變。
