# %% [markdown]
# 3. Suppose we estimate the regression coefficients in a linear regression model by minimizing (formula) for a particular value of s. For parts (a) through (e), indicate which of i. through v. is correct. Justify your answer.

# %% [markdown]
# (a) As we increase
# 𝑠
# s from 0, the training RSS will:
# Answer: (iv) Steadily decrease.
# Explanation:
# Training RSS measures how well the model fits the training data. As
# 𝑠
# s increases, the model becomes more flexible and can better adapt to the training data. This results in a steady decrease in training RSS, as the model minimizes errors on the training set regardless of generalization.

# %% [markdown]
# (b) As we increase
# 𝑠
# s from 0, the test RSS will:
# Answer: (ii) Decrease initially, and then eventually start increasing in a U shape.
# Explanation:
# Test RSS reflects the model's performance on unseen data. Initially, as
# 𝑠
# s increases, the model reduces bias and fits the true patterns in the data better, leading to a decrease in test RSS. However, beyond a certain point, the model starts overfitting the training data (capturing noise instead of patterns), which increases test RSS. This forms a U-shaped curve.

# %% [markdown]
# (c) As we increase
# 𝑠
# s from 0, the variance will:
# Answer: (iii) Steadily increase.
# Explanation:
# Variance measures how sensitive the model is to changes in the training data. As
# 𝑠
# s increases, the model becomes more complex and flexible, causing predictions to vary significantly with small changes in the training data. Hence, variance increases steadily.

# %% [markdown]
# (d) As we increase
# 𝑠
# s from 0, the (squared) bias will:
# Answer: (iv) Steadily decrease.
# Explanation:
# Squared bias measures systematic error due to model simplicity. A simple model (low
# 𝑠
# s) cannot fully capture the true patterns in the data, leading to high bias. As
# 𝑠
# s increases, the model becomes more capable of fitting the data and reduces bias steadily.

# %% [markdown]
# (e) As we increase
# 𝑠
# s from 0, the irreducible error will:
# Answer: (v) Remain constant.
# Explanation:
# The irreducible error is due to noise and variability inherent in the data, not the model. It is independent of
# 𝑠
# s or the model’s complexity, so it remains constant.

# %% [markdown]
# Summary of Answers:
# (a) Training RSS: (iv) Steadily decrease.
# (b) Test RSS: (ii) Decrease initially, and then eventually start increasing in a U shape.
# (c) Variance: (iii) Steadily increase.
# (d) Squared Bias: (iv) Steadily decrease.
# (e) Irreducible Error: (v) Remain constant.
