# %% [markdown]
# Ch12_Q02
#
# Suppose that we have four observations, for which we compute a
# dissimilarity matrix, given by

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (a) On the basis of this dissimilarity matrix, sketch the dendrogram
# that results from hierarchically clustering these four observations using complete linkage. Be sure to indicate on the plot the
# height at which each fusion occurs, as well as the observations
# corresponding to each leaf in the dendrogram.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (b) Repeat (a), this time using single linkage clustering

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (c) Suppose that we cut the dendrogram obtained in (a) such that
# two clusters result. Which observations are in each cluster?

# %% [markdown]
# If we cut the dendrogram at a height just below 0.8, we will have two clusters：
#
# - Cluster 1: {Observation 1, Observation 2}
#
# - Cluster 2: {Observation 3, Observation 4}

# %% [markdown]
# (d) Suppose that we cut the dendrogram obtained in (b) such that
# two clusters result. Which observations are in each cluster?

# %% [markdown]
# If we cut the dendrogram at a height just below 0.4, we will get two cluster：
#
# - Cluster 1: {Observation 1, Observation 2}
#
# - Cluster 2: {Observation 3, Observation 4}

# %% [markdown]
# (e) It is mentioned in this chapter that at each fusion in the dendrogram, the position of the two clusters being fused can be
# swapped without changing the meaning of the dendrogram. Draw
# a dendrogram that is equivalent to the dendrogram in (a), for
# which two or more of the leaves are repositioned, but for which
# the meaning of the dendrogram is the same.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ch12_Q03
#
# In this problem, you will perform K-means clustering manually, with
# K = 2, on a small example with n = 6 observations and p = 2
# features. The observations are as follows.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (a) Plot the observations.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (b) Randomly assign a cluster label to each observation. You can use
# the np.random.choice() function to do this. Report the cluster
# labels for each observation.

# %%
import numpy as np

# Define the observations with their X1 and X2 coordinates
observations = {
    "Obs 1": [1, 4],
    "Obs 2": [1, 3],
    "Obs 3": [0, 4],
    "Obs 4": [5, 1],
    "Obs 5": [6, 2],
    "Obs 6": [4, 0]
}

# List of observation labels
labels = list(observations.keys())

# Number of clusters
K = 2

# Randomly assigning cluster labels (1 or 2) to each observation
np.random.seed(0)  # Setting seed for reproducibility
cluster_labels = np.random.choice([1, 2], size=len(observations))

# Creating a dictionary to map observations to their cluster labels
cluster_assignment = {label: cluster for label, cluster in zip(labels, cluster_labels)}

# Print the cluster assignments
print(cluster_assignment)
# Out:
# {'Obs 1': 1, 'Obs 2': 2, 'Obs 3': 2, 'Obs 4': 1, 'Obs 5': 2, 'Obs 6': 2}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (c) Compute the centroid for each cluster.

# %% [markdown]
# - Cluster 1 (Red): Centroid at [3.0,2.5]
# - Cluster 2 (Blue): Centroid at [2.75,2.55]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (d) Assign each observation to the centroid to which it is closest, in
# terms of Euclidean distance. Report the cluster labels for each
# observation.

# %% [markdown]
# Observation 1: Cluster 2
#
# Observation 2: Cluster 2
#
# Observation 3: Cluster 2
#
# Observation 4: Cluster 1
#
# Observation 5: Cluster 1
#
# Observation 6: Cluster 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (e) Repeat (c) and (d) until the answers obtained stop changing.

# %% [markdown]
# Final Centroids:
#
# - Centroid 1 (Cluster 1): [5.0,1.0]
# - Centroid 2 (Cluster 2): [0.67,3.67]
#
# Final Cluster Labels:
#
# - Observation 1: Cluster 2
# - Observation 2: Cluster 2
# - Observation 3: Cluster 2
# - Observation 4: Cluster 1
# - Observation 5: Cluster 1
# - Observation 6: Cluster 1

# %% [markdown]
# (f) In your plot from (a), color the observations according to the
# cluster labels obtained.

# %% [markdown]
# ![image.png](attachment:image.png)
