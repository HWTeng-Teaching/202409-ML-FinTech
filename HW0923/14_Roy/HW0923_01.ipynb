# %% [markdown]
# ##Suppose that we have four observations, for which we compute a dissimilarity matrix, given by[[nil,0.3,0.4,0.7],[0.3,nil,0.5,0.8],[0.4,0.5,nil,0.45],[0.7,0.8,0.45,nil]]
# ##For instance, the dissimilarity between the first and second obser- vations is 0.3, and the dissimilarity between the second and fourth observations is 0.8.

# %% [markdown]
# ###(a) On the basis of this dissimilarity matrix, sketch the dendrogram that results from hierarchically clustering these four observa- tions using complete linkage. Be sure to indicate on the plot the height at which each fusion occurs, as well as the observations corresponding to each leaf in the dendrogram.

# %%
import numpy as np
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

dissimilarity_matrix = np.array([
    [0.0, 0.3, 0.4, 0.7],
    [0.3, 0.0, 0.5, 0.8],
    [0.4, 0.5, 0.0, 0.45],
    [0.7, 0.8, 0.45, 0.0]
])

linkage_matrix = sch.linkage(sch.distance.squareform(dissimilarity_matrix), method='complete')

plt.figure(figsize=(8, 5))
dendrogram = sch.dendrogram(linkage_matrix, labels=['Obs 1', 'Obs 2', 'Obs 3', 'Obs 4'])

plt.title('Hierarchical Clustering Dendrogram (Complete Linkage)')
plt.xlabel('Observations')
plt.ylabel('Distance (Dissimilarity)')

plt.show()

# %% [markdown]
# ###(b) Repeat (a), this time using single linkage clustering.

# %%
import numpy as np
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

dissimilarity_matrix = np.array([
    [0.0, 0.3, 0.4, 0.7],
    [0.3, 0.0, 0.5, 0.8],
    [0.4, 0.5, 0.0, 0.45],
    [0.7, 0.8, 0.45, 0.0]
])


linkage_matrix_single = sch.linkage(sch.distance.squareform(dissimilarity_matrix), method='single')


plt.figure(figsize=(8, 5))
dendrogram_single = sch.dendrogram(linkage_matrix_single, labels=['Obs 1', 'Obs 2', 'Obs 3', 'Obs 4'])


plt.title('Hierarchical Clustering Dendrogram (Single Linkage)')
plt.xlabel('Observations')
plt.ylabel('Distance (Dissimilarity)')


plt.show()

# %% [markdown]
# ###(c) Suppose that we cut the dendrogram obtained in (a) such that two clusters result. Which observations are in each cluster?

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
import numpy as np
from scipy.cluster.hierarchy import fcluster

dissimilarity_matrix = np.array([
    [0, 0.3, 0.4, 0.7],
    [0.3, 0, 0.5, 0.8],
    [0.4, 0.5, 0, 0.45],
    [0.7, 0.8, 0.45, 0]
])

condensed_dissimilarity = sch.distance.squareform(dissimilarity_matrix)

Z = sch.linkage(condensed_dissimilarity, method='complete')

plt.figure(figsize=(8, 6))
dendrogram = sch.dendrogram(Z, labels=['Obs 1', 'Obs 2', 'Obs 3', 'Obs 4'])
plt.title("Hierarchical Clustering Dendrogram (Complete Linkage)")
plt.xlabel("Observations")
plt.ylabel("Dissimilarity (Height)")
plt.show()

max_d = 0.65

clusters_complete = fcluster(Z, t=max_d, criterion='distance')

clusters_complete
# Out:
# array([1, 1, 2, 2], dtype=int32)

# %% [markdown]
# C1:{Obs1,Obs2}
#
# C2: {Obs3,Obs4}

# %% [markdown]
# ###(d) Suppose that we cut the dendrogram obtained in (b) such that two clusters result. Which observations are in each cluster?

# %% [markdown]
# C1:{Obs1,Obs2,Obs3}
#
# C2: {Obs4}

# %% [markdown]
# ###(e) It is mentioned in this chapter that at each fusion in the den- drogram, the position of the two clusters being fused can be swapped without changing the meaning of the dendrogram. Draw a dendrogram that is equivalent to the dendrogram in (a), for which two or more of the leaves are repositioned, but for which the meaning of the dendrogram is the same.

# %%
plt.figure(figsize=(8, 6))

dendrogram_swapped = sch.dendrogram(Z, labels=['Obs 2', 'Obs 1', 'Obs 4', 'Obs 3'])

plt.title("Equivalent Hierarchical Clustering Dendrogram (Complete Linkage)")
plt.xlabel("Observations")
plt.ylabel("Dissimilarity (Height)")

plt.show()
