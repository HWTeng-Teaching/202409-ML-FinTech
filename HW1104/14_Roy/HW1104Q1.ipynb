# %% [markdown]
# To prove that $\alpha$ given by (5.6) minimizes the variance of the linear combination $\alpha X + (1 - \alpha) Y$, we start by setting up the variance expression and using calculus to minimize it.
#
# ### Step 1: Set up the variance expression
#
# Let $Z = \alpha X + (1 - \alpha) Y$. We want to minimize the variance of $Z$, which is given by:
#
# $$
# \text{Var}(Z) = \text{Var}(\alpha X + (1 - \alpha) Y)
# $$
#
# Using the properties of variance, we expand this as:
#
# $$
# \text{Var}(Z) = \alpha^2 \text{Var}(X) + (1 - \alpha)^2 \text{Var}(Y) + 2 \alpha (1 - \alpha) \text{Cov}(X, Y)
# $$
#
# Let $\sigma_X^2 = \text{Var}(X)$, $\sigma_Y^2 = \text{Var}(Y)$, and $\sigma_{XY} = \text{Cov}(X, Y)$. Then the expression becomes:
#
# $$
# \text{Var}(Z) = \alpha^2 \sigma_X^2 + (1 - \alpha)^2 \sigma_Y^2 + 2 \alpha (1 - \alpha) \sigma_{XY}
# $$
#
# ### Step 2: Differentiate with respect to $\alpha$ and set the derivative to zero
#
# To find the value of $\alpha$ that minimizes $\text{Var}(Z)$, we take the derivative with respect to $\alpha$ and set it equal to zero:
#
# $$
# \frac{d}{d\alpha} \left( \alpha^2 \sigma_X^2 + (1 - \alpha)^2 \sigma_Y^2 + 2 \alpha (1 - \alpha) \sigma_{XY} \right) = 0
# $$
#
# Expanding and differentiating term by term, we get:
#
# - For $\alpha^2 \sigma_X^2$: $\frac{d}{d\alpha} (\alpha^2 \sigma_X^2) = 2 \alpha \sigma_X^2$
# - For $(1 - \alpha)^2 \sigma_Y^2$: $\frac{d}{d\alpha} ((1 - \alpha)^2 \sigma_Y^2) = -2 (1 - \alpha) \sigma_Y^2$
# - For $2 \alpha (1 - \alpha) \sigma_{XY}$: $\frac{d}{d\alpha} (2 \alpha (1 - \alpha) \sigma_{XY}) = 2 \sigma_{XY} (1 - 2\alpha)$
#
# Thus, the derivative is:
#
# $$
# 2 \alpha \sigma_X^2 - 2 (1 - \alpha) \sigma_Y^2 + 2 \sigma_{XY} (1 - 2\alpha) = 0
# $$
#
# Dividing through by 2, we get:
#
# $$
# \alpha \sigma_X^2 - (1 - \alpha) \sigma_Y^2 + \sigma_{XY} (1 - 2\alpha) = 0
# $$
#
# Expanding and rearranging terms gives:
#
# $$
# \alpha \sigma_X^2 + \alpha \sigma_Y^2 + 2 \alpha \sigma_{XY} = \sigma_Y^2 + \sigma_{XY}
# $$
