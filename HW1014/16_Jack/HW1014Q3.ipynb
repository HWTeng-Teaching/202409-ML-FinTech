# %% [markdown]
# # HW1014Q3 CH03Q15

# %% [markdown]
# ### 15. This problem involves the Boston data set, which we saw in the lab for this chapter. We will now try to predict per capita crime rate using the other variables in this data set. In other words, per capita crime rate is the response, and the other variables are the predictors.

# %%
from ISLP import load_data

# Load Boston dataset from ISLP
boston_df = load_data('Boston')

# Display first few rows of the data
print(boston_df.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# ##### (a) For each predictor, fit a simple linear regression model to predict the response. Describe your results. In which of the models is there a statistically signifcant association between the predictor and the response? Create some plots to back up your assertions.

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

predictors = boston_df.columns.drop('crim')  


results_a = {}

for predictor in predictors:
    X = sm.add_constant(boston_df[predictor])  
    y = boston_df['crim']  
    model = sm.OLS(y, X).fit()  
    results_a[predictor] = model  
    print(f"\nPredictor: {predictor}")
    print(model.summary())

    plt.figure(figsize=(6, 4))
    plt.scatter(boston_df[predictor], boston_df['crim'], label='Data')
    plt.plot(boston_df[predictor], model.fittedvalues, color='red', label='Fitted line')
    plt.xlabel(predictor)
    plt.ylabel('Per capita crime rate (crim)')
    plt.title(f'Per capita crime rate vs {predictor}')
    plt.legend()
    plt.show()

print("Most of predictors have statistically signifcant with the response.")
# Out:
# Predictor: zn
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     21.10
# Date:                Thu, 17 Oct 2024   Prob (F-statistic):           5.51e-06
# Time:                        01:08:35   Log-Likelihood:                -1796.0
# No. Observations:                 506   AIC:                             3596.
# Df Residuals:                     504   BIC:                             3604.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.4537      0.417     10.675      0.000       3.634       5.273
# ...

# %% [markdown]
# ##### (b) Fit a multiple regression model to predict the response using all of the predictors. Describe your results. For which predictors can we reject the null hypothesis H0 : βj = 0?

# %%
X_all = sm.add_constant(boston_df[predictors])  # Add intercept
model_all = sm.OLS(boston_df['crim'], X_all).fit()  # Fit the model
print("\nMultiple Regression Model Summary:")
print(model_all.summary())
print("zn, dis, rad, medv are reject the null hypothesis H0 : βj = 0.")
# Out:
# Multiple Regression Model Summary:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     33.52
# Date:                Thu, 17 Oct 2024   Prob (F-statistic):           2.03e-56
# Time:                        01:08:36   Log-Likelihood:                -1655.4
# No. Observations:                 506   AIC:                             3337.
# Df Residuals:                     493   BIC:                             3392.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.7784      7.082      1.946      0.052      -0.136      27.693
# ...

# %% [markdown]
# ##### (c) How do your results from (a) compare to your results from (b)? Create a plot displaying the univariate regression coefcients from (a) on the x-axis, and the multiple regression coefcients from (b) on the y-axis. That is, each predictor is displayed as a single point in the plot. Its coeffcient in a simple linear regression model is shown on the x-axis, and its coeffcient estimate in the multiple linear regression model is shown on the y-axis.

# %%
import numpy as np

coeffs_a = np.array([results_a[predictor].params.iloc[1] for predictor in predictors])
coeffs_b = model_all.params.iloc[1:]


plt.figure(figsize=(6, 6))
plt.scatter(coeffs_a, coeffs_b)
plt.xlabel('Univariate Regression Coefficients')
plt.ylabel('Multiple Regression Coefficients')
plt.title('Univariate vs Multiple Regression Coefficients')
plt.axhline(0, color='grey', linestyle='--')
plt.axvline(0, color='grey', linestyle='--')
plt.show()

# %% [markdown]
# ##### (d) Is there evidence of non-linear association between any of the predictors and the response? To answer this question, for each predictor X, fit a model of the form
# Y = β0 + β1X + β2X2 + β3X3 + e.

# %%
import pandas as pd

for predictor in predictors:
    X_poly = pd.DataFrame({
        'X': boston_df[predictor],
        'X^2': boston_df[predictor] ** 2,
        'X^3': boston_df[predictor] ** 3
    })
    X_poly = sm.add_constant(X_poly)  
    model_poly = sm.OLS(boston_df['crim'], X_poly).fit()
    print(f"\nPolynomial Regression for {predictor} (up to cubic terms):")
    print(model_poly.summary())

    plt.figure(figsize=(6, 4))
    plt.scatter(boston_df[predictor], boston_df['crim'], label='Data')
    plt.plot(boston_df[predictor], model_poly.fittedvalues, color='red', label='Fitted Polynomial')
    plt.xlabel(predictor)
    plt.ylabel('Per capita crime rate (crim)')
    plt.title(f'Non-linear relationship of CRIM with {predictor}')
    plt.legend()
    plt.show()

print("zn, chas, rm, age, tax, lstat, medv have non-linear association with the response.")
# Out:
# Polynomial Regression for zn (up to cubic terms):
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     10.35
# Date:                Thu, 17 Oct 2024   Prob (F-statistic):           1.28e-06
# Time:                        01:08:36   Log-Likelihood:                -1791.2
# No. Observations:                 506   AIC:                             3590.
# Df Residuals:                     502   BIC:                             3607.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.8461      0.433     11.192      0.000       3.995       5.697
# ...
