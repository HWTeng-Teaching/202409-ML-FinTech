# %% [markdown]
# # Ch_02_Q08 in (p.65)

# %% [markdown]
# This exercise relates to the College data set, which can be found in the fle College.csv on the book website. It contains a number of variables for 777 diferent universities and colleges in the US. The variables are:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question A

# %% [markdown]
# Use the pd.read_csv() function to read the data into Python. Call the loaded data college. Make sure that you have the directory set to the correct location for the data.

# %%
college = pd.read_csv('/Users/chenpinyu/Downloads/College.csv')
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# ## Question B

# %% [markdown]
# Look at the data used in the notebook by creating and running a new cell with just the code college in it. You should notice that the frst column is just the name of each university in a column named something like Unnamed: 0. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later. Try the following commands and similarly look at the resulting data frames:

# %%
#1
college2 = pd.read_csv('/Users/chenpinyu/Downloads/College.csv', index_col=0)
college2.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
college3 = college3.set_index('College')
college = college3
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# ## Question C

# %% [markdown]
# Use the describe() method of to produce a numerical summary of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ## Question D

# %% [markdown]
# Use the pd.plotting.scatter_matrix() function to produce a scatterplotmatrixofthefirstcolumns[Top10perc, Apps, Enroll]. Recall that you can reference a list C of columns of a data frame
# A using A[C].

# %%
C = ['Top10perc','Apps','Enroll']
scatterplot = pd.plotting.scatter_matrix(pd.DataFrame(college[C]))
scatterplot
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# ## Question E

# %% [markdown]
# Use the boxplot() method of college to produce side-by-side boxplots of Outstate versus Private.

# %%
boxplot = college.boxplot('Outstate','Private')
boxplot
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# ## Question F

# %% [markdown]
# Create a new qualitative variable, called Elite, by binning the Top10perc variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.

# %%
college['Elite'] = pd.cut(college['Top10perc']/college['Enroll'],[0,0.5,1],labels=['No', 'Yes'])
college['Elite'].value_counts()
# Out:
# Elite
# No     775
# Yes      2
# Name: count, dtype: int64

# %%
college.boxplot('Outstate','Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# ## Question G

# %% [markdown]
# Use the plot.hist() method of college to produce some his- tograms with differing numbers of bins for a few of the quanti- tative variables. The command plt.subplots(2, 2) may be use- ful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %%
fig, ax = plt.subplots(2,2)
college['Apps'].hist(ax=ax[0,0], bins=10)
college['Accept'].hist(ax=ax[0,1], bins=20)
college['Enroll'].hist(ax=ax[1,0], bins=30)
college['Top10perc'].hist(ax=ax[1,1], bins=40)
# Out:
# <Axes: >

# %% [markdown]
# ## Question H

# %% [markdown]
# Continue exploring the data, and provide a brief summary of what you discover.

# %%
# Explore the relationship between 'perc.alumni' and 'Outstate'
plt.scatter(college['perc.alumni'], college['Outstate'])
plt.xlabel('perc.alumni')
plt.ylabel('Outstate')
plt.title('perc.alumni vs. Outstate')
plt.show()

# Calculate the correlation between 'Outstate' and 'F.Undergrad'
corr_outstate_funder = college['Outstate'].corr(college['F.Undergrad'])
print(f"Correlation between Outstate and F.Undergrad: {corr_outstate_funder}")


# Investigate the relationship between 'Private' and 'Grad.Rate'
college.boxplot('Grad.Rate', 'Private')
plt.title('Grad.Rate by Private Status')
plt.show()
# Out:
# Correlation between Outstate and F.Undergrad: -0.21574199877041914
