# %% [markdown]
# # Introduction to Statistical Learning, Chapter 2.4, Question 8 (P.65)

# %% [markdown]
# This exercise relates to the College data set, which can be found in
# the fle College.csv on the book website. It contains a number of
# variables for 777 diferent universities and colleges in the US. The
# variables are:

# %% [markdown]
# # Question (a).

# %% [markdown]
# Use the pd.read_csv() function to read the data into Python. Call
# the loaded data college. Make sure that you have the directory
# set to the correct location for the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
college = pd.read_csv("/content/drive/MyDrive/Machine Learning and FinTech/HW1_0916/HW0916_01/College.csv")
print(college.head())
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# # Question (b).

# %% [markdown]
# Look at the data used in the notebook by creating and running
# a new cell with just the code college in it. You should notice
# that the frst column is just the name of each university in a
# column named something like **Unnamed: 0**. We don’t really want
# pandas to treat this as data. However, it may be handy to have
# these names for later. Try the following commands and similarly
# look at the resulting data frames:

# %%
college2 = pd.read_csv("/content/drive/MyDrive/Machine Learning and FinTech/HW1_0916/HW0916_01/College.csv", index_col = 0)
print(college2.head())
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# This has used the frst column in the fle as an index for the
# data frame. This means that pandas has given each row a name
# corresponding to the appropriate university. Now you should see
# that the frst data column is Private. Note that the names of
# the colleges appear on the left of the table. We also introduced
# a new python object above: a dictionary, which is specifed by dictionary (key, value) pairs. Keep your modifed version of the data with the following:

# %%
college3 = college.rename({"Unnamed: 0": "College"}, axis=1) # 0 same as "index", 1 same as "columns"
print(college3.head())
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college = college3
print(college.head())
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# # Question (c).

# %% [markdown]
# Use the describe() method of to produce a numerical summary
# of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# # Question (d).

# %% [markdown]
# Use the pd.plotting.scatter_matrix() function to produce a
# scatterplot matrix of the frst columns [Top10perc, Apps, Enroll].
# Recall that you can reference a list C of columns of a data frame
# A using A[C].

# %%
# pandas.plotting.scatter_matrix: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html
scatterplot_matrix = pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']], figsize=(10,10))

# %% [markdown]
# # Question (e).

# %% [markdown]
# Use the boxplot() method of college to produce side-by-side
# boxplots of Outstate versus Private.

# %%
college
boxplot = college.boxplot(column='Outstate', by='Private')

# %% [markdown]
# # Question (f).

# %% [markdown]
# Create a new qualitative variable, called **Elite**, by binning the
# Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%.

# %%
college['Elite.Rate'] = college['Top10perc'] / college['Enroll']
print(college.head())
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college["Elite"] = pd.cut(college["Elite.Rate"], bins = [0, 0.5, 1], labels = ["No", "Yes"])
print(college.head())
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  ...  Books  Personal  PhD  \
# 0         52         2885          537      7440  ...    450      2200   70
# 1         29         2683         1227     12280  ...    750      1500   29
# 2         50         1036           99     11250  ...    400      1165   53
# 3         89          510           63     12960  ...    450       875   92
# 4         44          249          869      7560  ...    800      1500   76
#
# ...

# %% [markdown]
# Use the value_counts() method of college['Elite'] to see how
# many elite universities there are. Finally, use the boxplot() method
# again to produce side-by-side boxplots of Outstate versus Elite.

# %%
elite_count = college["Elite"].value_counts()
print(elite_count)
# Out:
# Elite
# No     775
# Yes      2
# Name: count, dtype: int64

# %%
elite_boxplot = college.boxplot(column = 'Outstate', by = 'Elite')

# %% [markdown]
# # Question (g).

# %% [markdown]
# Use the plot.hist() method of college to produce some histograms with difering numbers of bins for a few of the quantitative variables. The command plt.subplots(2, 2) may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %%
data1 = college['Apps']
data2 = college['Accept']
data3 = college['Enroll']
data4 = college['Grad.Rate']

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

axs[0, 0].hist(data1, bins=50) # bins = 10
axs[0, 0].set_title('App')

axs[0, 1].hist(data2, bins=50)
axs[0, 1].set_title('Accept')

axs[1, 0].hist(data3, bins=50)
axs[1, 0].set_title('Enroll')

axs[1, 1].hist(data4, bins=50)
axs[1, 1].set_title('Grad.Rate')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Question (h).
# Continue exploring the data, and provide a brief summary of what you discover.

# %% [markdown]
# I would like to observe the accept rate and gradutation rate for top100 university.

# %%
college['Rank.Rate'] = college['Top25perc'] / college['Enroll']
Top100Uni = college.sort_values('Rank.Rate', ascending=False).head(100)
print(Top100Uni)
# Out:
#                        College Private  Apps  Accept  Enroll  Top10perc  \
# 85             Capitol College     Yes   100      90      35         10
# 110        Christendom College     Yes    81      72      51         33
# 764             Wilson College     Yes   167     130      46         16
# 539       Southwestern College     Yes   213     155      75         28
# 4    Alaska Pacific University     Yes   193     146      55         16
# ..                         ...     ...   ...     ...     ...        ...
# 106             Centre College     Yes  1013     888     288         55
# 617      University of Dubuque     Yes   576     558     137         11
# 519         Seton Hill College     Yes   936     794     197         24
# 452          Pikeville College     Yes   404     400     169         28
# 67         Briar Cliff College     Yes   392     351     155         16
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  ...  Personal  PhD  \
# ...

# %%
college['Top25perc_larger_Enroll'] = college['Top25perc'] > college['Enroll']
print(college['Top25perc_larger_Enroll'].value_counts(), end='\n\n')

print('The college which has Top25perc larger than Enroll students.:')
for index, row in college.iterrows():
  if row['Top25perc_larger_Enroll'] == True:
    print(index, row['College'])
# Out:
# Top25perc_larger_Enroll
# False    774
# True       3
# Name: count, dtype: int64
#
# The college which has Top25perc larger than Enroll students.:
# 85 Capitol College
# 110 Christendom College
# 764 Wilson College

# %%
filtered_college = college[college['Top25perc'] <= college['Enroll']]
Top100Uni = filtered_college.sort_values('Rank.Rate', ascending=False).head(100)
print(Top100Uni)
# Out:
#                                    College Private  Apps  Accept  Enroll  \
# 539                   Southwestern College     Yes   213     155      75
# 4                Alaska Pacific University     Yes   193     146      55
# 397               Mount St. Mary's College     Yes   657     537     113
# 734                          Wells College     Yes   318     240     130
# 3                      Agnes Scott College     Yes   417     349     137
# ..                                     ...     ...   ...     ...     ...
# 452                      Pikeville College     Yes   404     400     169
# 67                     Briar Cliff College     Yes   392     351     155
# 750  Westminster College of Salt Lake City     Yes   917     720     213
# 726                     Washington College     Yes  1209     942     214
# 291              Kentucky Wesleyan College     Yes   584     497     175
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  ...  PhD  \
# ...

# %%
data1 = Top100Uni['Accept'] / Top100Uni['Apps']
data2 = Top100Uni['Grad.Rate']

fig, axs = plt.subplots(2, 1, figsize=(10, 4))

axs[0].hist(data1, bins=50)
axs[0].set_title('Accept')

axs[1].hist(data2, bins=50)
axs[1].set_title('Grad.Rate')

plt.tight_layout()
plt.show()

# %%
Top100Uni['Accept.Rate'] = Top100Uni['Accept'] / Top100Uni['Apps']
scatter_plot_matrix = pd.plotting.scatter_matrix(Top100Uni[['Accept.Rate', 'Rank.Rate']], figsize=(10,10))
